# %% [markdown]
# # Milestone 1
#
# This assignment will place you and your team in the posture of a newly formed partnership between SprawlMart's legal and engineering departments. We have read of rising concerns over the potentially discriminatory behavior of certain algorithmic hiring tools and now you'll be expected to address these concerns from technical, legal, and business perspectives. SprawlMart's CEO and General Counsel have become increasingly wary of potential probes from the EEOC into its latest adoption of algorithmic hiring practices. Moreover, apart from potential liability from the feds, a whole host of state legislatures have passed or begun to consider laws regulating the use of automated evaluation algorithms demanding explainability and transparency among other measures.
#
# Your team of Stanford-trained lawyers and engineers have been tasked with the job of analyzing potential problems in the latest dataset of candidates applying for SprawlMart's coveted Entry-Level Business/Sales Associate Position. You will be tasked with analyzing the liability risks that the company faces and prototyping a system that shields the corporation from those risks while balancing other key corporate objectives.

# %% [markdown]
# ## Exercise 1
# So you've read some about these automated algorithmic hiring techniques but what do they actually do with the data fed to them?  To try and gain some intuitions, we've exposed a sample of 25 past employees, below.  Take a look at the candidates and the data features and discuss with your team to get a sense for how you would "rank" or "classify them" if you were the hiring manager.

# %%
# RUN THIS CELL #
import pandas as pd
# RUN THIS CELL #

# %%
# RUN THIS CELL #
sampleEmployees = pd.read_csv("25employees.csv")
sampleEmployees
# RUN THIS CELL #
# Out:
#                   Names   GPA  Avg Commute Time  Cultural Fit  \
# 0           Andre White  3.25                 8             1
# 1          Danny Gugler  2.81                32             0
# 2              Gary Liu  3.13                41             1
# 3           Holly Zheng  3.79                 0             0
# 4    Jeffrey Challender  4.10                 1             2
# 5        Dorothy Howard  3.15                31             0
# 6              Vicki Wu  3.89               100             1
# 7         Harvey Hunter  3.28                70             2
# 8      Marshall Johnson  2.67                47             2
# 9       Kurt Deoliveira  2.90                35             2
# 10      Cynthia Hinojos  3.37                40             1
# 11        Lester Morrow  3.25                31             2
# 12  Christopher Burcham  3.32                29             1
# 13          Sherika Ray  3.56                13             2
# ...

# %% [markdown]
# ### Task 1: Classify 5 "Label" Employees
# One way of understanding some machine learning algorithms especially in classification tasks is that they are attempting to learn certain weights to attach to features of the data sample that will maximize the ability to predict some label or class of that data sample.
#
# Sometimes those labels are pretty straightforward - a photo either contains a cat or it does not contain a cat. But other times its more difficult - in our case, we might want to classify employees into certain buckets. Suppose for example that we wanted to bucket these 25 employees into five categories. "Excellent", "Good", "Satisfactory", "Poor", "Very Poor".
#
# ##### Questions:
# - Your first task is to choose one employee for each label, whom your team believes is the employee most representative of that label. You might just choose to label 5 employees based on your team's intuitive judgement of their data features, or you might try and come up with a complex formulaic method of choosing your 5, it's up to you.
#
# - After you choose your 5 representative employees - please explain in your writeup how you came to your classifications.

# %%
# Describe and explain your approach.

# %% [markdown]
# ### Task 2: Come up with your own classification
#
# - Ok, now try and come up with labels for all 25 employees. How would you classify not just 5 employees into 5 respective labels, but all of the employees with labels? You can again just choose to label employees based on your intuitions or try and come up with your own systematic method of classification.  Will you have 5 labels? 3? 2?
# - Explain your team's method and how you decided to use it.

# %%
# Describe and explain your approach.
